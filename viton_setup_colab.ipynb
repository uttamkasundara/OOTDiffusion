# %% [markdown]
# <a href="https://colab.research.google.com/github/uttamkasundara/OOTDiffusion/blob/main/viton_setup_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/levihsu/OOTDiffusion.git
# Out:
# Cloning into 'OOTDiffusion'...
# remote: Enumerating objects: 800, done.
# remote: Counting objects: 100% (81/81), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 800 (delta 47), reused 27 (delta 27), pack-reused 719 (from 1)
# Receiving objects: 100% (800/800), 27.31 MiB | 45.04 MiB/s, done.
# Resolving deltas: 100% (149/149), done.

# %%
pip install torch==2.0.1 torchvision==0.15.2 torchaudio==2.0.2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 119.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 117.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 104.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 104.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 62.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 12.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 MB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.2/173.2 MB 5.8 MB/s eta 0:00:00
# ...

# %%
cd OOTDiffusion
# Out:
# /content/OOTDiffusion

# %%
pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.8/126.8 kB 9.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 5.4 MB/s eta 0:00:00
# ...
# WARNING: typer 0.16.0 does not provide the extra 'all'
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 113.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.1/34.1 MB 23.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 124.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 MB 11.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 106.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 88.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 123.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.9/270.9 kB 25.1 MB/s eta 0:00:00
# ...

# %%
# !pip uninstall numpy -y
# Out:
# Found existing installation: numpy 1.24.4
# Uninstalling numpy-1.24.4:
#   Successfully uninstalled numpy-1.24.4

# %%
# !pip uninstall huggingface_hub -y
# Out:
# Found existing installation: huggingface-hub 0.33.4
# Uninstalling huggingface-hub-0.33.4:
#   Successfully uninstalled huggingface-hub-0.33.4

# %%
# !pip uninstall fsspec -y
# Out:
# Found existing installation: fsspec 2025.3.2
# Uninstalling fsspec-2025.3.2:
#   Successfully uninstalled fsspec-2025.3.2

# %%
# !pip install numpy==1.25 fsspec==2025.3.0 huggingface_hub==0.19.4
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 67.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 19.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.7/311.7 kB 28.8 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 4.1.0 requires huggingface-hub>=0.20.0, but you have huggingface-hub 0.19.4 which is incompatible.
# sentence-transformers 4.1.0 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.36.2 which is incompatible.
# jaxlib 0.5.1 requires scipy>=1.11.1, but you have scipy 1.10.1 which is incompatible.
# xarray-einstats 0.9.1 requires scipy>=1.11, but you have scipy 1.10.1 which is incompatible.
# treescope 0.1.9 requires numpy>=1.25.2, but you have numpy 1.25.0 which is incompatible.
# ...

# %%
# !git lfs install
# Out:
# Git LFS initialized.

# %%
mkdir -p checkpoints

# %%
cd checkpoints/
# Out:
# /content/checkpoints

# %%
# !git clone https://huggingface.co/levihsu/OOTDiffusion
# Out:
# Cloning into 'OOTDiffusion'...
# remote: Enumerating objects: 105, done.
# remote: Counting objects: 100% (101/101), done.
# remote: Compressing objects: 100% (96/96), done.
# remote: Total 105 (delta 29), reused 0 (delta 0), pack-reused 4 (from 1)
# Receiving objects: 100% (105/105), 2.61 MiB | 20.38 MiB/s, done.
# Resolving deltas: 100% (29/29), done.
# Filtering content: 100% (12/12), 14.77 GiB | 38.90 MiB/s, done.

# %%
# !mkdir -p source_code/OOTDiffusion/checkpoints/
# !mv  OOTDiffusion/checkpoints/* /content/OOTDiffusion/checkpoints/

# %%
from huggingface_hub import snapshot_download
import os

# Define the model ID and the local directory to save the model
model_id = "openai/clip-vit-large-patch14"
save_directory = "/content/OOTDiffusion/checkpoints/clip-vit-large-patch14"

# Create the directory if it doesn't exist
os.makedirs(save_directory, exist_ok=True)

# Download the model files
snapshot_download(repo_id=model_id, local_dir=save_directory, local_dir_use_symlinks=False)

print(f"Downloaded {model_id} to {save_directory}")

# %%
cd /content/OOTDiffusion/run
# Out:
# /content/OOTDiffusion/run

# %%
# !python run_ootd.py --model_path "examples/model/01008_00.jpg" --cloth_path "examples/garment/00055_00.jpg" --scale 2.0 --sample 4
# Out:
# 2025-07-19 10:16:46.594550: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752920206.615620    7575 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752920206.622050    7575 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/transformers/utils/import_utils.py", line 1382, in _get_module
#     return importlib.import_module("." + module_name, self.__name__)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
# !pip install --upgrade accelerate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 367.1/367.1 kB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.3/515.3 kB 32.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface-hub 0.19.4
#     Uninstalling huggingface-hub-0.19.4:
#       Successfully uninstalled huggingface-hub-0.19.4
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 0.26.1
#     Uninstalling accelerate-0.26.1:
#       Successfully uninstalled accelerate-0.26.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 4.1.0 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.36.2 which is incompatible.
# ...

# %%
# !pip install transformers==4.36.2 accelerate==0.26.1 huggingface_hub==0.20.0 sentence-transformers==2.2.2
# Out:
# ...
#   Using cached accelerate-0.26.1-py3-none-any.whl.metadata (18 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 3.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
# Using cached accelerate-0.26.1-py3-none-any.whl (270 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 329.1/329.1 kB 14.7 MB/s eta 0:00:00
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=66133d5d120d17e76c54576aa5535ae78d7345bac8526c34d996c7dc6a693787
#   Stored in directory: /root/.cache/pip/wheels/ff/27/bf/ffba8b318b02d7f691a57084ee154e26ed24d012b0c7805881
# Successfully built sentence-transformers
# ...
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface-hub 0.19.4
#     Uninstalling huggingface-hub-0.19.4:
#       Successfully uninstalled huggingface-hub-0.19.4
#   Attempting uninstall: sentence-transformers
#     Found existing installation: sentence-transformers 4.1.0
# ...

# %%
# !pip uninstall peft -y
# Out:
# Found existing installation: peft 0.16.0
# Uninstalling peft-0.16.0:
#   Successfully uninstalled peft-0.16.0

# %%
# !python run_ootd.py --model_path "examples/model/01008_00.jpg" --cloth_path "examples/garment/00055_00.jpg" --scale 2.0 --sample 4
# Out:
# 2025-07-19 10:22:30.621435: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752920550.642232    9115 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752920550.648496    9115 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.96it/s]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/transformers/utils/hub.py", line 389, in cached_file
#     resolved_file = hf_hub_download(
#                     ^^^^^^^^^^^^^^^^
# ...

# %%
from huggingface_hub import snapshot_download
import os

# Define the model ID and the local directory to save the model
model_id = "openai/clip-vit-large-patch14"
save_directory = "/content/OOTDiffusion/checkpoints/clip-vit-large-patch14"

# Create the directory if it doesn't exist
os.makedirs(save_directory, exist_ok=True)

# Download the model files
snapshot_download(repo_id=model_id, local_dir=save_directory, local_dir_use_symlinks=False)

print(f"Downloaded {model_id} to {save_directory}")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/_login.py:337: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# flax_model.msgpack:   0%|          | 0.00/1.71G [00:00<?, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.71G [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.71G [00:00<?, ?B/s]
# ...

# %%
# %cd /content/OOTDiffusion/run
# !python run_ootd.py --model_path "examples/model/01008_00.jpg" --cloth_path "examples/garment/00055_00.jpg" --scale 2.0 --sample 4
# Out:
# /content/OOTDiffusion/run
# 2025-07-19 10:31:13.834910: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752921073.855706   11319 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752921073.861939   11319 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Loading pipeline components...: 100% 7/7 [00:01<00:00,  4.97it/s]
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# ...

# %%
# %cd /content/OOTDiffusion/results/
# !ls -l
# Out:
# [Errno 2] No such file or directory: '/content/OOTDiffusion/results/'
# /content/OOTDiffusion/run
# total 36
# drwxr-xr-x 4 root root  4096 Jul 19 09:50 examples
# -rw-r--r-- 1 root root 12184 Jul 19 09:50 gradio_ootd.py
# drwxr-xr-x 2 root root  4096 Jul 19 09:50 images_output
# drwxr-xr-x 2 root root  4096 Jul 19 10:08 __pycache__
# -rw-r--r-- 1 root root  3031 Jul 19 09:50 run_ootd.py
# -rw-r--r-- 1 root root  7673 Jul 19 09:50 utils_ootd.py

# %%
# %cd /content/OOTDiffusion/run/images_output
# !ls -l
# Out:
# /content/OOTDiffusion/run/images_output
# total 2808
# -rw-r--r-- 1 root root  66037 Jul 19 10:32 mask.jpg
# -rw-r--r-- 1 root root 692060 Jul 19 10:34 out_hd_0.png
# -rw-r--r-- 1 root root 701300 Jul 19 10:34 out_hd_1.png
# -rw-r--r-- 1 root root 701951 Jul 19 10:34 out_hd_2.png
# -rw-r--r-- 1 root root 703296 Jul 19 10:34 out_hd_3.png
